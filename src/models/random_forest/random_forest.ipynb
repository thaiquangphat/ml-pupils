# %% [markdown]
# #  Dataset

# %%
import pandas as pd
import os
import shutil
import random
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np

# %% [markdown]
# ## Data Downloading
#
# Use the downloading from Kaggle CLI.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/brain-tumor-mri-dataset

# %%
# !mv /kaggle/input/brain-tumor-mri-dataset ./
# Out:
# Streaming output truncated to the last 5000 lines.
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1157.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0125.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0699.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1273.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0374.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1370.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1171.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1484.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0816.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0085.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0029.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1285.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0210.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0385.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0335.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0198.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0576.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1429.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0209.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0476.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0197.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0798.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1230.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1432.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1578.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0467.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1120.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1094.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1422.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1590.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1068.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0339.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0344.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0452.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0135.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0504.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0764.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1003.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1317.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-noTr_0009.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1401.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1078.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1146.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1498.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1339.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0826.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0695.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1301.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1438.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0024.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0299.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0346.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1148.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1138.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1514.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1134.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0089.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1577.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0325.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0780.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1272.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0964.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0888.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1045.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1090.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0445.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0822.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0249.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0959.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1576.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0546.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0276.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0416.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0423.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1153.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0279.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1512.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1353.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1064.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0569.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0242.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1570.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1260.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0582.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1386.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0181.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1250.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0650.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1071.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0583.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1108.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1275.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0941.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1111.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0427.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1436.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1131.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0965.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0994.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0366.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0800.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0136.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1460.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0655.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1394.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1276.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0212.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0306.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1523.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1062.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0760.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0473.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1462.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0937.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1130.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0902.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1377.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1506.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0639.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0829.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1212.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0785.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0543.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0438.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-noTr_0003.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0314.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1248.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0413.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1181.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0501.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1127.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0512.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0475.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1351.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0448.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1428.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0387.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0787.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0678.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0947.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1228.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0810.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1340.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0982.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1568.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0412.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0720.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0905.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0137.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0091.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1385.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0179.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0308.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0027.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0241.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1026.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0955.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0384.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1093.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1043.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0850.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0274.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1532.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1529.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0532.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0573.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-noTr_0007.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0355.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0770.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0377.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0157.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0643.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1278.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1152.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0729.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0032.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0160.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0707.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0144.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0669.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0262.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0895.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1320.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0622.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1247.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0498.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0670.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1103.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0596.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0191.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0939.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0866.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0218.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1586.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0772.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0253.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1427.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1232.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1437.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1361.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1328.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0428.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0444.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0456.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1206.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1288.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0911.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0917.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0833.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0099.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1126.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0961.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0966.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0989.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0848.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0795.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0105.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0238.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0979.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0967.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0619.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0725.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0059.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1354.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0020.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1243.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0400.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1256.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0929.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0975.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0141.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0533.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1102.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0030.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1472.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0667.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1072.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0086.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0484.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1166.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1496.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1362.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1091.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0514.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1279.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0167.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0393.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1244.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0797.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1562.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0221.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1417.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1589.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1549.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1163.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1158.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1374.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0022.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1239.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1541.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0831.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0283.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0088.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0237.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0094.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1216.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0920.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1536.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1074.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1558.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0280.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0903.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1208.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0228.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0856.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1282.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0769.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1314.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0170.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0631.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1042.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0999.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1499.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0159.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1318.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0072.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0855.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1114.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0916.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0574.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0057.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0312.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1008.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1579.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1402.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1497.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0972.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1543.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0750.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0649.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0110.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0493.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0663.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0761.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0093.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0974.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0038.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0316.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0594.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0128.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0951.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0293.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1476.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0394.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0863.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1189.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1389.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0820.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1141.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1449.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0194.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0131.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1076.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1053.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0319.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1356.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0252.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1433.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0451.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1528.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1326.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0738.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0219.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0496.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0938.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0601.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1287.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0153.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0420.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1344.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0112.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0028.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0371.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0886.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0563.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1490.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1117.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0351.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1494.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0440.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0383.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1086.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0697.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1128.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0126.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0719.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0021.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1368.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1392.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0178.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1504.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1164.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0944.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0694.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0360.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1524.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1487.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0095.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0405.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0621.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0379.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1269.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0205.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1404.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1380.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1005.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0691.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1420.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0173.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0130.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0392.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1560.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1308.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1303.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0503.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1322.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1395.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0867.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0704.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0635.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1080.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1025.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1439.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0215.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1070.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0322.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1261.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0875.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1491.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0188.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1425.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0735.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1325.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1393.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0447.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0914.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0586.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0396.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1556.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1159.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1403.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0679.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0064.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1555.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0071.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0603.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0076.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0149.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1238.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_1330.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0388.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0115.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0861.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Training/notumor/Tr-no_0196.jpg': Read-only file system
# ...
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0221.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0181.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0017.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0291.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0242.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0083.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0133.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0195.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0225.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0178.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0222.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0141.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0251.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0261.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0164.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0296.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0193.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0236.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0167.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0104.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0223.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0022.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0069.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0237.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0131.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0149.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0177.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0057.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0184.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0116.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0240.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0025.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0135.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0180.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0171.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0053.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0294.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0105.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0115.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0137.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0058.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0262.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0197.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0145.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0047.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0086.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0271.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0011.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0024.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0067.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0257.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0140.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0183.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0148.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0094.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0012.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0021.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0041.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0000.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0005.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0112.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0084.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0273.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0093.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0247.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0207.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0060.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0283.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0102.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0143.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0224.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0077.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0068.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0042.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0124.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0208.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0152.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0258.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0103.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0054.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0006.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0134.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0156.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0274.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0229.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0051.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0287.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0279.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0191.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0122.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0232.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0045.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0154.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0055.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0194.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0127.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0198.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0098.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0213.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0082.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0218.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0037.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0029.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0190.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0119.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0032.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0002.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0253.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0204.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0090.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0013.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0095.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0285.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0036.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0129.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0286.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0214.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0298.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0267.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0176.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0065.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0081.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0101.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0217.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0254.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0076.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0147.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0111.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0158.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0040.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0227.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0088.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0189.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0202.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0089.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0142.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0220.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0200.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0270.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0107.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0288.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0108.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0004.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/brain-tumor-mri-dataset/Testing/glioma/Te-gl_0250.jpg': Read-only file system

# %%
# Function to load and preprocess each image
def process_image(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.random_saturation(image, lower=0.8, upper=1.2)
    image = tf.image.random_hue(image, max_delta=0.1)
    return image, label

# %% [markdown]
# ## Train, Test, Validation

# %% [markdown]
# Create train, test, validation.

# %%
base_dir = 'brain-tumor-mri-dataset'
training_dir = os.path.join(base_dir, 'Training')
validation_dir = os.path.join(base_dir, 'Validation')
testing_dir = os.path.join(base_dir, 'Testing')

# %%
if not os.path.exists(validation_dir):
    os.makedirs(validation_dir)
    for class_name in os.listdir(training_dir):
        class_val_dir = os.path.join(validation_dir, class_name)
        if not os.path.exists(class_val_dir):
            os.makedirs(class_val_dir)

# %%
random.seed(42)  # For reproducibility
val_split = 0.2

for class_name in os.listdir(training_dir):
    class_train_dir = os.path.join(training_dir, class_name)
    class_val_dir = os.path.join(validation_dir, class_name)

    if os.path.isdir(class_train_dir):
        # List all files in the class directory
        files = [f for f in os.listdir(class_train_dir) if os.path.isfile(os.path.join(class_train_dir, f))]
        random.shuffle(files)  # Shuffle files randomly

        # Calculate number of files for validation
        val_size = int(len(files) * val_split)

        # Split files
        val_files = files[:val_size]
        train_files = files[val_size:]

        # Move validation files to Validation directory
        for file in val_files:
            src = os.path.join(class_train_dir, file)
            dst = os.path.join(class_val_dir, file)
            shutil.move(src, dst)

# %% [markdown]
# Create tf dataset.

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory('brain-tumor-mri-dataset/Training',
                                                                 label_mode="categorical",
                                                                 batch_size=32,
                                                                 image_size=(224, 224))

val_data = tf.keras.preprocessing.image_dataset_from_directory('brain-tumor-mri-dataset/Validation',
                                                                 label_mode="categorical",
                                                                 batch_size=32,
                                                                 image_size=(224, 224))

test_data = tf.keras.preprocessing.image_dataset_from_directory('brain-tumor-mri-dataset/Testing',
                                                                 label_mode="categorical",
                                                                 image_size=(224, 224),
                                                                 shuffle=False)
# Out:
# Found 4571 files belonging to 4 classes.
# Found 1141 files belonging to 4 classes.
# Found 1311 files belonging to 4 classes.

# %%
train_dataset_augmented = train_data.map(process_image)

# %% [markdown]
# ## Visualization

# %%
def count_files_in_directory(directory):
    label_counts = {}
    # Iterate over subdirectories (class1, class2, class3, class4)
    for class_name in os.listdir(directory):
        class_dir = os.path.join(directory, class_name)
        if os.path.isdir(class_dir):
            # Count image files in the class subdirectory
            files = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))]
            label_counts[class_name] = len(files)
    return label_counts

# %%
train_label_counts = count_files_in_directory(training_dir)
val_label_counts = count_files_in_directory(validation_dir)
test_label_counts = count_files_in_directory(testing_dir)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10, 3), sharey=True)

# Training set
ax1.bar(train_label_counts.keys(), train_label_counts.values(), color='skyblue')
ax1.set_title('Training Set Distribution')
ax1.set_ylabel('Samples Count')
ax1.tick_params(axis='x', rotation=45)

# Validation set
ax2.bar(val_label_counts.keys(), val_label_counts.values(), color='lightgreen')
ax2.set_title('Validation Set Distribution')
ax2.tick_params(axis='x', rotation=45)

# Test set
ax3.bar(test_label_counts.keys(), test_label_counts.values(), color='salmon')
ax3.set_title('Test Set Distribution')
ax3.tick_params(axis='x', rotation=45)

# %% [markdown]
# # Train Model
#
# Train model for feature extraction.

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (3.8.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, LSTM, Reshape, BatchNormalization, Flatten, Dense
from keras.applications.vgg19 import VGG19
from keras.optimizers import Adam
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import tensorflow as tf
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from math import floor
from collections import Counter

# %% [markdown]
# ## Hyperparameters

# %%
EPOCHS = 1
INIT_LR = 1e-3
decay_rate = 0.95
decay_step = 1
IMAGE_SIZE = [224, 224]

# %% [markdown]
# ## Base Model

# %%
def Combined_model():
    # Input layer
    input_layer = Input(shape=(224, 224, 3))

    # Base VGG19 model as a feature extractor
    baseModel = VGG19(weights='imagenet', include_top=False, input_tensor=input_layer)

    # Freeze the layers of the VGG19 model
    for layer in baseModel.layers:
        layer.trainable = False

    x = baseModel.output

    # LSTM layer
    x = Reshape((49, 512))(x)
    x = LSTM(512, activation="relu", return_sequences=True, trainable=False)(x)
    x = BatchNormalization()(x)

    # Flatten output from LSTM
    x = Flatten()(x)

    # Output layer
    output = Dense(4, activation='softmax')(x)

    # Define the model
    model = Model(inputs=input_layer, outputs=output)

    opt = Adam(learning_rate=INIT_LR)
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=["accuracy"])

    return model

# %%
model = Combined_model()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 49, 512)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 49, 512)        │     2,099,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 49, 512)        │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │       100,356 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,225,988 (84.79 MB)
#  Trainable params: 101,380 (396.02 KB)
#  Non-trainable params: 22,124,608 (84.40 MB)

# %% [markdown]
# ## Training Arguments

# %%
save_model_path = '/content/drive/MyDrive/ml-hcmut/model/fe_model.weights.h5'

checkpoint = ModelCheckpoint(filepath=save_model_path,
                             monitor='val_accuracy',
                             mode='max',
                             verbose=1,
                             save_best_only=True,
                             save_weights_only=True)
earlystop = EarlyStopping(monitor='accuracy',
                          min_delta=0,
                          patience=15,
                          verbose=1,
                          mode='max')
lr_scheduler = LearningRateScheduler(lambda epoch: INIT_LR * pow(decay_rate, floor(epoch / decay_step)))

# %% [markdown]
# ## Training

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.18.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
history = model.fit(train_dataset_augmented,
                    epochs=EPOCHS,
                    steps_per_epoch=len(train_dataset_augmented),
                    validation_data=val_data,
                    callbacks=[checkpoint, earlystop, lr_scheduler])
# Out:
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.7269 - loss: 1.0532
# Epoch 1: val_accuracy improved from -inf to 0.79404, saving model to /content/drive/MyDrive/ml-hcmut/model/svm_fe_model.weights.h5
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 75s 383ms/step - accuracy: 0.7274 - loss: 1.0515 - val_accuracy: 0.7940 - val_loss: 1.0928 - learning_rate: 0.0010

# %% [markdown]
# # Extracting Features

# %%
def extract_features(data_generator, model):
    features = []
    labels = []
    for images, batch_labels in data_generator:
        batch_features = model.predict(images)
        features.append(batch_features)
        labels.append(batch_labels.numpy())  # Convert labels to numpy arrays

    # Concatenate all the features and labels
    features = np.concatenate(features, axis=0)
    labels = np.concatenate(labels, axis=0)

    return features, labels

# %%
train_features, train_labels = extract_features(train_data, model)
test_features, test_labels = extract_features(test_data, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step

# %%
train_labels = np.argmax(train_labels, axis=1)
test_labels = np.argmax(test_labels, axis=1)

# %% [markdown]
# # Training Random Forest

# %%
scaler = StandardScaler()
num_samples, num_features = train_features.shape
pca_components = min(num_samples, num_features, 64)  # Adjust the number of PCA components as needed
pca = PCA(n_components=pca_components)
rf_model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# %%
train_features_scaled = scaler.fit_transform(train_features)
train_features_pca = pca.fit_transform(train_features_scaled)

# %%
rf_model.fit(train_features_pca, train_labels)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %% [markdown]
# ### Report

# %%
test_features_scaled = scaler.transform(test_features)
test_features_pca = pca.transform(test_features_scaled)
accuracy = rf_model.score(test_features_pca, test_labels)
print(f'Random Forest Accuracy: {accuracy}')
# Out:
# Random Forest Accuracy: 0.8672768878718535

# %%
from sklearn.metrics import classification_report

test_predictions = rf_model.predict(test_features_pca)

report = classification_report(test_labels, test_predictions, target_names=test_data.class_names)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.90      0.71      0.80       300
#   meningioma       0.71      0.82      0.76       306
#      notumor       0.95      0.98      0.96       405
#    pituitary       0.91      0.92      0.92       300
#
#     accuracy                           0.87      1311
#    macro avg       0.87      0.86      0.86      1311
# weighted avg       0.87      0.87      0.87      1311

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Predict the labels of the test set using the trained SVM
test_predictions = rf_model.predict(test_features_pca)

# Generate the confusion matrix
cm = confusion_matrix(test_labels, test_predictions)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_data.class_names, yticklabels=test_data.class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Random Forest Implemented

# %%
class DecisionTree:
    def __init__(self, max_depth=10, min_samples_split=2, n_features=None):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.n_features = n_features  # for Random Forest
        self.tree = None

    def fit(self, X, y):
        self.n_classes_ = len(set(y))
        self.n_features_ = X.shape[1] if self.n_features is None else self.n_features
        self.tree = self._grow_tree(X, y)

    def _grow_tree(self, X, y, depth=0):
        n_samples, n_features = X.shape
        num_labels = len(set(y))

        if depth >= self.max_depth or num_labels == 1 or n_samples < self.min_samples_split:
            leaf_value = self._most_common_label(y)
            return {"leaf": leaf_value}

        feat_idxs = np.random.choice(n_features, self.n_features_, replace=False)
        best_feat, best_thresh = self._best_split(X, y, feat_idxs)

        if best_feat is None:
            return {"leaf": self._most_common_label(y)}

        left_idxs = X[:, best_feat] < best_thresh
        right_idxs = X[:, best_feat] >= best_thresh

        # Check for empty splits
        if len(y[left_idxs]) == 0 or len(y[right_idxs]) == 0:
            return {"leaf": self._most_common_label(y)}

        left = self._grow_tree(X[left_idxs], y[left_idxs], depth + 1)
        right = self._grow_tree(X[right_idxs], y[right_idxs], depth + 1)

        return {"feature": best_feat, "threshold": best_thresh, "left": left, "right": right}


    def _best_split(self, X, y, feat_idxs):
        best_gain = -1
        split_idx, split_thresh = None, None

        for idx in feat_idxs:
            thresholds = np.unique(X[:, idx])
            for t in thresholds:
                gain = self._information_gain(y, X[:, idx], t)

                if gain > best_gain:
                    best_gain = gain
                    split_idx = idx
                    split_thresh = t
        return split_idx, split_thresh

    def _information_gain(self, y, X_column, split_thresh):
        left_mask = X_column < split_thresh
        right_mask = ~left_mask
        if sum(left_mask) == 0 or sum(right_mask) == 0:
            return 0

        p = len(y)
        entropy_before = self._entropy(y)
        entropy_after = (len(y[left_mask]) / p) * self._entropy(y[left_mask]) + \
                        (len(y[right_mask]) / p) * self._entropy(y[right_mask])
        return entropy_before - entropy_after

    def _entropy(self, y):
        hist = np.bincount(y)
        ps = hist / len(y)
        return -np.sum([p * np.log2(p) for p in ps if p > 0])

    def _most_common_label(self, y):
        return Counter(y).most_common(1)[0][0]

    def predict(self, X):
        return np.array([self._predict(inputs, self.tree) for inputs in X])

    def _predict(self, x, tree):
        if "leaf" in tree:
            return tree["leaf"]
        if x[tree["feature"]] < tree["threshold"]:
            return self._predict(x, tree["left"])
        else:
            return self._predict(x, tree["right"])

# %%
class RandomForest:
    def __init__(self, n_estimators=10, max_depth=10, min_samples_split=2):
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.trees = []

    def fit(self, X, y):
        self.trees = []
        n_samples, n_features = X.shape
        for _ in range(self.n_estimators):
            idxs = np.random.choice(n_samples, n_samples, replace=True)
            tree = DecisionTree(max_depth=self.max_depth, min_samples_split=self.min_samples_split,
                                n_features=int(np.sqrt(n_features)))
            tree.fit(X[idxs], y[idxs])
            self.trees.append(tree)

    def predict(self, X):
        tree_preds = np.array([tree.predict(X) for tree in self.trees])
        # majority vote
        return np.apply_along_axis(lambda x: Counter(x).most_common(1)[0][0], axis=0, arr=tree_preds)

# %%
clf = RandomForest(n_estimators=10, max_depth=10)
clf.fit(train_features_pca, train_labels)

# %% [markdown]
# ## Report

# %%
from sklearn.metrics import classification_report

test_predictions = clf.predict(test_features_pca)

report = classification_report(test_labels, test_predictions, target_names=test_data.class_names)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.89      0.70      0.78       300
#   meningioma       0.69      0.75      0.72       306
#      notumor       0.92      0.97      0.94       405
#    pituitary       0.89      0.92      0.91       300
#
#     accuracy                           0.85      1311
#    macro avg       0.85      0.84      0.84      1311
# weighted avg       0.85      0.85      0.85      1311

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Predict the labels of the test set using the trained SVM
test_predictions = clf.predict(test_features_pca)

# Generate the confusion matrix
cm = confusion_matrix(test_labels, test_predictions)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_data.class_names, yticklabels=test_data.class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Training Analysis

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
